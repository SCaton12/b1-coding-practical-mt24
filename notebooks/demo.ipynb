# %%
# You can double-check your Python path like this...
import sys  
sys.path.insert(1, "C:\\Users\\Samca\\OneDrive\\Documents\\University Of Oxford\\Third Year\\B1 Engineering Computation\\b1-coding-practical-mt24")
print(sys.path)
# Out:
# ['C:\\Users\\Samca\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'C:\\Users\\Samca\\OneDrive\\Documents\\University Of Oxford\\Third Year\\B1 Engineering Computation\\b1-coding-practical-mt24', 'C:\\Users\\Samca\\OneDrive\\Documents\\University Of Oxford\\Third Year\\B1 Engineering Computation\\b1-coding-practical-mt24\\uuv_mission', 'C:\\Users\\Samca\\OneDrive\\Documents\\University Of Oxford\\Third Year\\B1 Engineering Computation\\b1-coding-practical-mt24\\uuv_mission', 'C:\\Users\\Samca\\OneDrive\\Documents\\University Of Oxford\\Third Year\\B1 Engineering Computation\\b1-coding-practical-mt24\\uuv_mission', 'C:\\Users\\Samca\\OneDrive\\Documents\\University Of Oxford\\Third Year\\B1 Engineering Computation\\b1-coding-practical-mt24\\uuv_mission\\dynamic.py', 'C:\\Users\\Samca\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'C:\\Users\\Samca\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'C:\\Users\\Samca\\AppData\\Local\\Programs\\Python\\Python312', 'c
# ...

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission.dynamic import *
from uuv_mission.control import controller

sub = Submarine()
# Instantiate your controller (depending on your implementation)


closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("C:\\Users\\Samca\\OneDrive\\Documents\\University Of Oxford\\Third Year\\B1 Engineering Computation\\b1-coding-practical-mt24\\data\\mission.csv") # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
